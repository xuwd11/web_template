# %% [markdown]
# ## Test
#
# This is a test.

# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Test output print

# %%
print('This is a test.')
# Out:
# This is a test.

# %% [markdown]
# ### Test plot

# %%
x = np.arange(0, 3, 0.1)
y = np.sin(x)

plt.figure(figsize=(7.5, 6))
plt.plot(x, y);
